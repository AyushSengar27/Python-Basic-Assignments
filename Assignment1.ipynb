# %% [markdown]
# 1. In the below elements which of them are values or an expression? eg:- values can be
# integer or string and expressions will be mathematical operators.
# *
#
# &#39;hello&#39;
#
# -87.8
#
# -
#
# /
#
# +
#
# 6

# %% [markdown]
# Values = 'hello' , -87.8 , 6
#
# Expressions = * , - , / , +

# %% [markdown]
# 2. What is the difference between string and variable?

# %% [markdown]
# Variable is a named memory location which is used to store values.
#
# String is a datatype, which is immutable in python and is usually written beetween single or double quotes

# %% [markdown]
# 3. Describe three different data types.

# %% [markdown]
# The three different data types are string, integer and float :
#
# String : String is a datatype, which is immutable in python and is usually written beetween single or double quotes
#
# Integer : It stores signed or unsigned whole number without any decimal places.
#
# Float : It stores numbers withdecimal places.

# %% [markdown]
# 4. What is an expression made up of? What do all expressions do?

# %% [markdown]
# An expression is made up of variables, values, operators or function calls and it evaluates to a single value.

# %% [markdown]
# 5.This assignment statements, like spam = 10. What is the difference between an
# expression and a statement?

# %% [markdown]
# Expression evaluates to a single value and the statement does not

# %% [markdown]
# 6. After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1

# %% [markdown]
# 22

# %% [markdown]
# 7.What should the values of the following two terms be?
#
# &#39;spam&#39; + &#39;spamspam&#39;
#
# &#39;spam&#39; * 3

# %% [markdown]
# spamspamspam

# %% [markdown]
# 8. Why is eggs a valid variable name while 100 is invalid?

# %% [markdown]
# That's because variable names can start from lowercase or uppercase letter but cant start with number

# %% [markdown]
# 9.What three functions can be used to get the integer, floating-point number, or string
# version of a value?

# %% [markdown]
# int()
#
# float()
#
# str()

# %% [markdown]
# 10. Why does this expression cause an error? How can you fix it?
# &#39;I have eaten &#39; + 99 + &#39; burritos.&#39;

# %% [markdown]
# You cant add string to a number, you need to convert the number into string before concatenating
#
# Example
#
# 'I have eaten'+str(99)+'burritos.'
